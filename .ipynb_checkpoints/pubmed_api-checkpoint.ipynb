# %%
from datetime import datetime
import json
import re
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tqdm as tqdm_module
import requests

# %reload_ext autoreload
# %autoreload 2
import pbmd_tools as pbmd

# %%
# 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  !!!!!!

# %%
db = 'pubmed'
domain = 'https://www.ncbi.nlm.nih.gov/entrez/eutils'
nresults = 100
query = '"github.com"[Title/Abstract] NOT "github.com"[Title]'
retmode = 'json'

# %%
queryLinkSearch = f'{domain}/esearch.fcgi?db={db}&retmax={nresults}&retmode={retmode}&term={query}'
response = requests.get(queryLinkSearch)
pubmedJson = response.json()
results = []
for paperId in pubmedJson["esearchresult"]["idlist"]:
    queryLinkSummary = f'{domain}/esummary.fcgi?db={db}&id={paperId}&retmode={retmode}'
    results.append({'paperId': paperId, 'metadata': requests.get(queryLinkSummary).json()})

# %%
df1 = pd.DataFrame.from_records(results)
df1["result"] = df1["metadata"].apply(lambda x: x["result"])
df1["PMID"] = df1["paperId"]
df1["PubDate"] = [d[k]["sortpubdate"] for d in df1["result"] for k in d.keys() if k != "uids"]
df1["PubDate"] = df1["PubDate"].apply(lambda x: datetime.strptime(x, "%Y/%m/%d %H:%M").strftime("%Y-%m-%d") if x else None)

id_list = pubmedJson["esearchresult"]["idlist"]
df1["DOI"] = None
for i in range(len(id_list)):
    articleid_list = results[i]['metadata']['result'][id_list[i]]["articleids"]
    for dic in articleid_list:
        if 'doi' in dic.values():
            df1["DOI"].iloc[i] = dic['value']
            
df1["Journal"] = [d[k]["fulljournalname"] for d in df1["result"] for k in d.keys() if k != "uids"]
df1["Title"] = [d[k]["title"] for d in df1["result"] for k in d.keys() if k != "uids"]
df1 = df1.drop(["paperId", "result", "metadata"], axis=1)
df1
# Out:
#         PMID     PubDate                               DOI  \
# 0   36798707  2023-01-31         10.3389/fpls.2023.1109314
# 1   36798459  2023-02-08                              None
# 2   36798308  2023-02-10         10.1101/2023.02.09.527886
# 3   36798258  2023-02-12         10.1101/2023.02.11.528027
# 4   36798154  2023-02-10         10.1101/2023.02.09.527740
# ..       ...         ...                               ...
# 95  36740003  2023-02-03          10.1016/j.ab.2023.115075
# 96  36739821  2023-02-02  10.1016/j.compbiomed.2023.106615
# 97  36739616  2023-02-05                10.1002/gepi.22517
# 98  36739333  2023-02-04        10.1038/s41437-023-00595-9
# 99  36738608  2023-01-28        10.1016/j.cmpb.2023.107374
#
#                                          Journal  \
# 0                     Frontiers in plant science
# 1                                          ArXiv
# 2      bioRxiv : the preprint server for biology
# 3      bioRxiv : the preprint server for biology
# 4      bioRxiv : the preprint server for biology
# ..                                           ...
# 95                       Analytical biochemistry
# 96             Computers in biology and medicine
# 97                          Genetic epidemiology
# 98                                      Heredity
# 99  Computer methods and programs in biomedicine
#
#                                                 Title
# 0   DFSP: A fast and automatic distance field-base...
# 1   Geometry-Complete Diffusion for 3D Molecule Ge...
# 2   IDSL.CSA: Composite Spectra Analysis for Chemi...
# 3   Foreign RNA spike-ins enable accurate allele-s...
# 4   Diffsig: Associating Risk Factors With Mutatio...
# ..                                                ...
# 95  DapNet-HLA: Adaptive dual-attention mechanism ...
# 96  BX2S-Net: Learning to reconstruct 3D spinal st...
# 97  Bayesian multivariant fine mapping using the L...
# 98  Meiosis at three loci in autotetraploids: Prob...
# 99  PyRaDiSe: A Python package for DICOM-RT-based ...
#
# [100 rows x 5 columns]

# %%
rate_limit = 3
request_count = 0

for id_iter in df1["PMID"]:  
    
    if request_count >= rate_limit:
        
        time.sleep(1)
        request_count = 0
        
    df1.loc[df1["PMID"] == id_iter,"Abstract"] = pbmd.get_abstract(id_iter)
    df1.loc[df1["PMID"] == id_iter,"GitHub_link_raw"] = ", ".join(pbmd.get_link(df1, id_iter))
    df1.loc[df1["PMID"] == id_iter,"GitHub_link_clean"] = ", ".join(pbmd.clean_link(df1.loc[df1["PMID"] == id_iter,"GitHub_link_raw"]))
    df1.loc[df1["PMID"] == id_iter, "Phrase"] = str(pbmd.get_phrase_with_link(df1, id_iter))
    
    request_count += 1
    
df1 = df1[["PMID", "PubDate", "DOI", "GitHub_link_raw", "GitHub_link_clean", "Journal", "Title", "Phrase", "Abstract"]]

# %%
# PMID = 36789260 - 2 links

# %%
#pd.options.display.max_colwidth = None
df1.head(50)
# Out:
#         PMID     PubDate                               DOI  \
# 0   36798707  2023-01-31         10.3389/fpls.2023.1109314
# 1   36798459  2023-02-08                              None
# 2   36798308  2023-02-10         10.1101/2023.02.09.527886
# 3   36798258  2023-02-12         10.1101/2023.02.11.528027
# 4   36798154  2023-02-10         10.1101/2023.02.09.527740
# 5   36794927  2023-02-16    10.1093/bioinformatics/btad093
# 6   36794924  2023-02-16    10.1093/bioinformatics/btad092
# 7   36794913  2023-02-16    10.1093/bioinformatics/btad094
# 8   36794911  2023-02-16    10.1093/bioinformatics/btad091
# 9   36794706  2023-02-16                  10.1002/mp.16287
# 10  36793016  2023-02-15        10.1186/s12874-023-01847-2
# 11  36792366  2023-02-16               10.1093/gbe/evad020
# 12  36792093  2023-02-09               10.5534/wjmh.220231
# 13  36791547  2023-02-07  10.1016/j.compbiomed.2023.106635
# 14  36791465  2023-02-15                  10.1002/sim.9684
# 15  36791286  2023-02-15          10.1021/acs.jcim.2c01498
# 16  36790845  2023-02-15               10.1093/bib/bbad057
# 17  36790067  2023-02-15    10.1093/bioinformatics/btad089
# 18  36790056  2023-02-15    10.1093/bioinformatics/btad087
# 19  36790055  2023-02-15    10.1093/bioinformatics/btad072
# 20  36789431  2023-01-29         10.1101/2023.01.27.525971
# 21  36789427  2023-01-20         10.1101/2023.01.19.524495
# 22  36789411  2023-01-28         10.1101/2023.01.27.525885
# 23  36789294  2023-02-02            10.1093/bioadv/vbad005
# 24  36789260  2023-01-27        10.1016/j.csbj.2023.01.034
# 25  36788560  2023-02-14        10.1186/s12911-023-02129-z
# 26  36788531  2023-02-14        10.1186/s12859-023-05166-7
# 27  36787234  2023-02-14              10.1093/bfgp/elad006
# 28  36786404  2023-02-14    10.1093/bioinformatics/btad081
# 29  36786403  2023-02-14    10.1093/bioinformatics/btad088
# 30  36785708  2023-02-08               10.7717/peerj.14779
# 31  36781633  2023-01-01       10.1007/978-1-0716-3024-2_3
# 32  36780251  2022-09-01      10.1007/978-3-031-21014-3_18
# 33  36780239  2022-09-01      10.1007/978-3-031-16437-8_15
# 34  36778474  2023-02-03         10.1101/2023.02.02.526809
# 35  36778452  2023-02-04         10.1101/2023.02.03.527015
# 36  36778443  2023-02-03         10.1101/2023.02.02.526869
# 37  36778393  2023-02-03         10.1101/2023.02.02.526837
# 38  36778280  2023-02-02         10.1101/2023.01.30.526317
# 39  36778272  2023-02-02       10.1101/2023.01.29.23285172
# 40  36778267  2023-02-03         10.1101/2023.02.02.526854
# 41  36778023  2023-01-26        10.3389/fphar.2023.1008330
# 42  36777556  2023-05-01        10.1016/j.bspc.2023.104672
# 43  36777398  2022-07-01      10.1109/CBMS55023.2022.00063
# 44  36777397  2022-07-01      10.1109/CBMS55023.2022.00064
# 45  36776914  2023-02-01     10.1016/j.heliyon.2023.e13545
# 46  36776820  2023-02-02                              None
# 47  36775347  2022-10-01        10.1038/s41374-022-00801-y
# 48  36775056  2023-02-10         10.1016/j.gpb.2023.01.006
# 49  36774895  2023-02-09  10.1016/j.compbiomed.2023.106634
#
#                                       GitHub_link_raw  \
# 0                           github.com/syau-miao/DFSP
# 1     github.com/BioinfoMachineLearning/bio-diffusion
# 2                              github.com/idslme/IDSL
# 3                github.com/gimelbrantlab/controlFreq
# 4                          github.com/jennprk/diffsig
# 5        github.com/GreyGuoweiChen/RNA_virus_detector
# 6                              github.com/G2Lab/ldmat
# 7                        github.com/BioColLab/PFresGO
# 8                  github.com/ccb-hms/BioPlexAnalysis
# 9                         github.com/corcor27/BUS-Set
# 10                           github.com/ljwa2323/MTNN
# 11                      github.com/isugifNF/polishCLR
# 12                          github.com/cgab-ncc/TarGA
# 13                          github.com/Leejyuan/MGNet
# 14                github.com/umich-biostatistics/zGPS
# 15                    github.com/GOMC-WSU/MoSDeF-GOMC
# 16                    github.com/HuiLiuCode/MDBuilder
# 17                      github.com/HassounLab/GNN-SOM
# 18                 github.com/meidanis-lab/rank-indel
# 19                   github.com/CompBioIPM/wpLogicNet
# 20                       github.com/chrishil1/ChromDL
# 21          github.com/biomedbigdata/circRNA-sponging
# 22                 github.com/KULL-Centre/FRETpredict
# 23                    github.com/PNNL-CompBio/Snekmer
# 24  github.com/aitgon/vtam, github.com/aitgon/vtam...
# 25                   github.com/1152545264/SwinUnet3D
# 26          github.com/kramerlab/Multi-Omics_analysis
# 27             github.com/YanhaoHuo/dysregulated-DNBs
# 28                               github.com/mofradlab
# 29                  github.com/leopold-weidner/DBDIpy
# 30                       github.com/EESI/Complet-Plus
# 31              github.com/wendelljpereira/DArTseqMet
# 32                 github.com/freshman97/LinTransUNet
# 33                   github.com/nikhilroxtomar/TGANet
# 34                         github.com/SlavovLab/DO-MS
# 35  github.com/AlexandrovLab/SigProfilerMatrixGene...
# 36               github.com/sandybioteck/RTCpredictor
# 37                     github.com/jessicabonnie/dandd
# 38                  github.com/AnantharamanLab/ViWrap
# 39                   github.com/Zhizhen-Zhao/IPTW-TBI
# 40                  github.com/KoslickiLab/L2-UniFrac
# 41                          github.com/PreMedKB/PAnno
# 42                       github.com/YishuLiu/SA-COVID
# 43                  github.com/nikhilroxtomar/MKDCNet
# 44             github.com/NoviceMAn-prog/FocalConvNet
# 45                              github.com/peterman65
# 46            github.com/rohdelab/nuclear_morphometry
# 47                  github.com/wangwangCCChen/CNN-Cox
# 48                      github.com/ddhostallero/tindl
# 49                         github.com/doganlab/scmags
#
#                                     GitHub_link_clean  \
# 0                  https://github.com/syau-miao/DFSP/
# 1   https://github.com/BioinfoMachineLearning/bio-...
# 2                     https://github.com/idslme/IDSL/
# 3       https://github.com/gimelbrantlab/controlFreq/
# 4                 https://github.com/jennprk/diffsig/
# 5   https://github.com/GreyGuoweiChen/RNA_virus_de...
# 6                     https://github.com/G2Lab/ldmat/
# 7               https://github.com/BioColLab/PFresGO/
# 8         https://github.com/ccb-hms/BioPlexAnalysis/
# 9                https://github.com/corcor27/BUS-Set/
# 10                  https://github.com/ljwa2323/MTNN/
# 11             https://github.com/isugifNF/polishCLR/
# 12                 https://github.com/cgab-ncc/TarGA/
# 13                 https://github.com/Leejyuan/MGNet/
# 14       https://github.com/umich-biostatistics/zGPS/
# 15           https://github.com/GOMC-WSU/MoSDeF-GOMC/
# 16           https://github.com/HuiLiuCode/MDBuilder/
# 17             https://github.com/HassounLab/GNN-SOM/
# 18        https://github.com/meidanis-lab/rank-indel/
# 19          https://github.com/CompBioIPM/wpLogicNet/
# 20              https://github.com/chrishil1/ChromDL/
# 21  https://github.com/biomedbigdata/circRNA-spong...
# 22        https://github.com/KULL-Centre/FRETpredict/
# 23           https://github.com/PNNL-CompBio/Snekmer/
# 24  https://github.com/aitgon/vtam, github.com/ait...
# 25          https://github.com/1152545264/SwinUnet3D/
# 26  https://github.com/kramerlab/Multi-Omics_analy...
# 27    https://github.com/YanhaoHuo/dysregulated-DNBs/
# 28                      https://github.com/mofradlab/
# 29         https://github.com/leopold-weidner/DBDIpy/
# 30              https://github.com/EESI/Complet-Plus/
# 31     https://github.com/wendelljpereira/DArTseqMet/
# 32        https://github.com/freshman97/LinTransUNet/
# 33          https://github.com/nikhilroxtomar/TGANet/
# 34                https://github.com/SlavovLab/DO-MS/
# 35  https://github.com/AlexandrovLab/SigProfilerMa...
# 36      https://github.com/sandybioteck/RTCpredictor/
# 37            https://github.com/jessicabonnie/dandd/
# 38         https://github.com/AnantharamanLab/ViWrap/
# 39          https://github.com/Zhizhen-Zhao/IPTW-TBI/
# 40         https://github.com/KoslickiLab/L2-UniFrac/
# 41                 https://github.com/PreMedKB/PAnno/
# 42              https://github.com/YishuLiu/SA-COVID/
# 43         https://github.com/nikhilroxtomar/MKDCNet/
# 44    https://github.com/NoviceMAn-prog/FocalConvNet/
# 45                     https://github.com/peterman65/
# 46   https://github.com/rohdelab/nuclear_morphometry/
# 47         https://github.com/wangwangCCChen/CNN-Cox/
# 48             https://github.com/ddhostallero/tindl/
# 49                https://github.com/doganlab/scmags/
#
#                                               Journal  \
# 0                          Frontiers in plant science
# 1                                               ArXiv
# 2           bioRxiv : the preprint server for biology
# 3           bioRxiv : the preprint server for biology
# 4           bioRxiv : the preprint server for biology
# 5                    Bioinformatics (Oxford, England)
# 6                    Bioinformatics (Oxford, England)
# 7                    Bioinformatics (Oxford, England)
# 8                    Bioinformatics (Oxford, England)
# 9                                     Medical physics
# 10                   BMC medical research methodology
# 11                       Genome biology and evolution
# 12                  The world journal of men's health
# 13                  Computers in biology and medicine
# 14                             Statistics in medicine
# 15       Journal of chemical information and modeling
# 16                        Briefings in bioinformatics
# 17                   Bioinformatics (Oxford, England)
# 18                   Bioinformatics (Oxford, England)
# 19                   Bioinformatics (Oxford, England)
# 20          bioRxiv : the preprint server for biology
# 21          bioRxiv : the preprint server for biology
# 22          bioRxiv : the preprint server for biology
# 23                            Bioinformatics advances
# 24  Computational and structural biotechnology jou...
# 25        BMC medical informatics and decision making
# 26                                 BMC bioinformatics
# 27                   Briefings in functional genomics
# 28                   Bioinformatics (Oxford, England)
# 29                   Bioinformatics (Oxford, England)
# 30                                              PeerJ
# 31       Methods in molecular biology (Clifton, N.J.)
# 32  Machine learning in medical imaging. MLMI (Wor...
# 33  Medical image computing and computer-assisted ...
# 34          bioRxiv : the preprint server for biology
# 35          bioRxiv : the preprint server for biology
# 36          bioRxiv : the preprint server for biology
# 37          bioRxiv : the preprint server for biology
# 38          bioRxiv : the preprint server for biology
# 39  medRxiv : the preprint server for health sciences
# 40          bioRxiv : the preprint server for biology
# 41                          Frontiers in pharmacology
# 42           Biomedical signal processing and control
# 43  Proceedings. IEEE International Symposium on C...
# 44  Proceedings. IEEE International Symposium on C...
# 45                                            Heliyon
# 46                                              ArXiv
# 47  Laboratory investigation; a journal of technic...
# 48              Genomics, proteomics & bioinformatics
# 49                  Computers in biology and medicine
#
#                                                 Title  \
# 0   DFSP: A fast and automatic distance field-base...
# 1   Geometry-Complete Diffusion for 3D Molecule Ge...
# 2   IDSL.CSA: Composite Spectra Analysis for Chemi...
# 3   Foreign RNA spike-ins enable accurate allele-s...
# 4   Diffsig: Associating Risk Factors With Mutatio...
# 5   VirBot: an RNA viral contig detector for metag...
# 6   LDmat: Efficiently Queryable Compression of Li...
# 7   PFresGO: an attention mechanism-based deep-lea...
# 8   BioPlexR and BioPlexPy: integrated data produc...
# 9   BUS-Set: A benchmark for quantitative evaluati...
# 10  Propensity score analysis with missing data us...
# 11  "polishCLR: a Nextflow workflow for polishing ...
# 12  OGT and FLAD1 Genes Had Significant Prognostic...
# 13  MG-Net: Multi-level global-aware network for t...
# 14  Mining adverse events in large frequency table...
# 15  MoSDeF-GOMC: Python Software for the Creation ...
# 16  MDBuilder: a PyMOL plugin for the preparation ...
# 17  Using Graph Neural Networks for Site-of-Metabo...
# 18  Generalizations of the Genomic Rank Distance t...
# 19  wpLogicNet: logic gate and structure inference...
# 20  ChromDL: A Next-Generation Regulatory DNA Clas...
# 21  circRNA-sponging: a pipeline for extensive ana...
# 22  FRETpredict: A Python package for FRET efficie...
# 23  Snekmer: a scalable pipeline for protein seque...
# 24  VTAM: A robust pipeline for validating metabar...
# 25  Swin Unet3D: a three-dimensional medical image...
# 26  A fair experimental comparison of neural netwo...
# 27  Detecting early-warning signals for influenza ...
# 28  GO Bench: Shared-hub for Universal Benchmarkin...
# 29  DBDIpy: a Python library for processing of unt...
# 30  Complet+: a computationally scalable method to...
# 31  Computational Protocol for DNA Methylation Pro...
# 32  Dynamic Linear Transformer for 3D Biomedical I...
# 33  TGANet: Text-guided attention for improved pol...
# 34  Data-Driven Optimization of DIA Mass-Spectrome...
# 35  Visualizing and exploring patterns of large mu...
# 36  RTCpredictor: Identification of Read-Through C...
# 37  DandD: efficient measurement of sequence growt...
# 38  ViWrap: A modular pipeline to identify, bin, c...
# 39  Data Imputation for Clinical Trial Emulation: ...
# 40  Finding phylogeny-aware and biologically meani...
# 41  PAnno: A pharmacogenomics annotation tool for ...
# 42  Self-paced Multi-view Learning for CT-based se...
# 43  Automatic Polyp Segmentation with Multiple Ker...
# 44  Video Capsule Endoscopy Classification using F...
# 45  A multistate model and its standalone tool to ...
# 46  Transport-based morphometry of nuclear structu...
# 47  A convolutional neural network model for survi...
# 48  Preclinical-to-clinical Anti-cancer Drug Respo...
# 49  scMAGS: Marker gene selection from scRNA-seq d...
#
#                                                Phrase  \
# 0   The source code can be found at \nhttps://gith...
# 1   The \nsource code, data, and instructions to t...
# 2   Detailed \ndocumentation and tutorials are pro...
# 3   VAILABILITY: Analysis pipeline for this approa...
# 4   Diffsig is implemented as an R package availab...
# 5   AVAILABILITY AND IMPLEMENTATION: \nhttps://git...
# 6   It can also be \naccessed through https://gith...
# 7   AVAILABILITY: PFresGO is available for academi...
# 8   pplications and downstream analyses are \navai...
# 9   All dataset and \narchitecture details are ava...
# 10  Our code is publicly available at https://gith...
# 11  \nHere, we describe polishCLR (https://github....
# 12  Twenty metabolic genes were \nidentified by ow...
# 13  The code is \navailable at: https://github.com...
# 14  The proposed method \nis implemented in an R p...
# 15  The MoSDeF-GOMC software is available on GitHu...
# 16  The source code \nand documentation of MDBuild...
# 17  AVAILABILITY: A python implementation of the t...
# 18  AVAILABILITY: Code and instructions available ...
# 19  AVAILABILITY AND IMPLEMENTATION: The datasets ...
# 20  AVAILABILITY: The ChromDL source code can be f...
# 21  AVAILABILITY: https://github.com/biomedbigdata...
# 22  RETpredict is open \nsource (GPLv3) and is ava...
# 23  \nCode and data used in this article, along wi...
# 24  VTAM is implemented in Python and available fr...
# 25  The code can be found at \nhttps://github.com/...
# 26  The source code of all experiments is availabl...
# 27  The source code of this paper can be \nfreely ...
# 28             ode is hosted at github.com/mofradlab,
# 29  rg/project/DBDIpy) or from GitHub \n(https://g...
# 30  Code and \nsupplementary information is availa...
# 31  The software is available at \nhttps://github....
# 32  Code is available \nhttps://github.com/freshma...
# 33  Codes are available at \nhttps://github.com/ni...
# 34  he source code is \navailable at: github.com/S...
# 35  The tool is freely available at \nhttps://gith...
# 36  In addition, \nRTCpredictor ( https://github.c...
# 37  DandD is open source software available at: \n...
# 38  ViWrap is publicly available via GitHub ( \nht...
# 39  The \nexperiment details and code are availabl...
# 40  A \nprototype implementation is provided at: \...
# 41  PAnno is available at \nhttps://github.com/Pre...
# 42  The SA-COVID dataset is publicly released at \...
# 43  The code of the proposed \nMKDCNet is availabl...
# 44  The code of the proposed FocalConvNet is \nava...
# 45  CONCLUSIONS: Our easy-to-use and freely access...
# 46  The source codes implementing our method is av...
# 47  The codes are available \nat the GitHub websit...
# 48  The code can be accessed at https://github.com...
# 49  scMAGS is \nmade freely available at https://g...
#
#                                              Abstract Repo_created_at  \
# 0   Front Plant Sci. 2023 Jan 31;14:1109314. doi: ...      2022-09-11
# 1   ArXiv. 2023 Feb 8:arXiv:2302.04313v1. Preprint...      2023-02-09
# 2   bioRxiv. 2023 Feb 10:2023.02.09.527886. doi: 1...            None
# 3   bioRxiv. 2023 Feb 12:2023.02.11.528027. doi: 1...      2022-06-17
# 4   bioRxiv. 2023 Feb 10:2023.02.09.527740. doi: 1...      2022-04-18
# 5   Bioinformatics. 2023 Feb 16:btad093. doi: 10.1...      2022-07-12
# 6   Bioinformatics. 2023 Feb 16:btad092. doi: 10.1...      2022-08-01
# 7   Bioinformatics. 2023 Feb 16:btad094. doi: 10.1...      2022-12-20
# 8   Bioinformatics. 2023 Feb 16:btad091. doi: 10.1...      2021-04-13
# 9   Med Phys. 2023 Feb 16. doi: 10.1002/mp.16287. ...      2020-09-27
# 10  BMC Med Res Methodol. 2023 Feb 15;23(1):41. do...      2022-05-08
# 11  Genome Biol Evol. 2023 Feb 16:evad020. doi: 10...      2021-06-08
# 12  World J Mens Health. 2023 Feb 9. doi: 10.5534/...      2018-01-11
# 13  Comput Biol Med. 2023 Feb 7;155:106635. doi: 1...      2022-06-24
# 14  Stat Med. 2023 Feb 15. doi: 10.1002/sim.9684. ...            None
# 15  J Chem Inf Model. 2023 Feb 15. doi: 10.1021/ac...      2022-03-21
# 16  Brief Bioinform. 2023 Feb 15:bbad057. doi: 10....      2017-10-04
# 17  Bioinformatics. 2023 Feb 15:btad089. doi: 10.1...      2022-07-19
# 18  Bioinformatics. 2023 Feb 15:btad087. doi: 10.1...      2022-08-12
# 19  Bioinformatics. 2023 Feb 15:btad072. doi: 10.1...      2022-07-23
# 20  bioRxiv. 2023 Jan 29:2023.01.27.525971. doi: 1...      2021-08-02
# 21  bioRxiv. 2023 Jan 20:2023.01.19.524495. doi: 1...      2021-01-08
# 22  bioRxiv. 2023 Jan 28:2023.01.27.525885. doi: 1...      2020-08-28
# 23  Bioinform Adv. 2023 Feb 2;3(1):vbad005. doi: 1...      2020-11-16
# 24  Comput Struct Biotechnol J. 2023 Jan 27;21:115...            None
# 25  BMC Med Inform Decis Mak. 2023 Feb 14;23(1):33...      2021-12-21
# 26  BMC Bioinformatics. 2023 Feb 14;24(1):45. doi:...      2022-07-20
# 27  Brief Funct Genomics. 2023 Feb 14:elad006. doi...      2022-11-24
# 28  Bioinformatics. 2023 Feb 14:btad081. doi: 10.1...            None
# 29  Bioinformatics. 2023 Feb 14:btad088. doi: 10.1...      2022-10-18
# 30  PeerJ. 2023 Feb 8;11:e14779. doi: 10.7717/peer...      2022-05-24
# 31  Methods Mol Biol. 2023;2638:23-36. doi: 10.100...      2022-06-17
# 32  Mach Learn Med Imaging. 2022 Sep;13583:171-180...      2022-06-01
# 33  Med Image Comput Comput Assist Interv. 2022 Se...      2022-05-09
# 34  bioRxiv. 2023 Feb 3:2023.02.02.526809. doi: 10...      2018-07-20
# 35  bioRxiv. 2023 Feb 4:2023.02.03.527015. doi: 10...      2018-08-27
# 36  bioRxiv. 2023 Feb 3:2023.02.02.526869. doi: 10...      2021-11-09
# 37  bioRxiv. 2023 Feb 3:2023.02.02.526837. doi: 10...      2022-04-25
# 38  bioRxiv. 2023 Feb 2:2023.01.30.526317. doi: 10...      2022-09-08
# 39  medRxiv. 2023 Feb 2:2023.01.29.23285172. doi: ...      2022-03-07
# 40  bioRxiv. 2023 Feb 3:2023.02.02.526854. doi: 10...      2021-02-17
# 41  Front Pharmacol. 2023 Jan 26;14:1008330. doi: ...      2022-07-26
# 42  Biomed Signal Process Control. 2023 May;83:104...      2022-03-23
# 43  Proc IEEE Int Symp Comput Based Med Syst. 2022...      2022-05-12
# 44  Proc IEEE Int Symp Comput Based Med Syst. 2022...      2022-05-15
# 45  Heliyon. 2023 Feb;9(2):e13545. doi: 10.1016/j....            None
# 46  ArXiv. 2023 Feb 2:arXiv:2302.01449v1. Preprint...            None
# 47  Lab Invest. 2022 Oct;102(10):1064-1074. doi: 1...      2022-03-23
# 48  Genomics Proteomics Bioinformatics. 2023 Feb 1...      2021-06-11
# 49  Comput Biol Med. 2023 Feb 9;155:106634. doi: 1...      2022-03-05
#
#    Repo_updated_at
# 0       2023-02-16
# 1       2023-02-15
# 2             None
# 3       2023-01-31
# 4       2023-02-17
# 5       2023-02-17
# 6       2022-09-26
# 7       2023-02-17
# 8       2023-02-17
# 9       2023-02-06
# 10      2023-02-17
# 11      2023-02-17
# 12      2022-09-04
# 13      2022-11-25
# 14            None
# 15      2023-02-16
# 16      2022-10-09
# 17      2023-02-15
# 18      2023-02-16
# 19      2023-02-17
# 20      2023-02-16
# 21      2023-01-15
# 22      2023-02-13
# 23      2023-02-06
# 24            None
# 25      2022-12-15
# 26      2023-02-13
# 27      2022-11-24
# 28            None
# 29      2023-02-15
# 30      2022-05-24
# 31      2022-09-09
# 32      2022-10-28
# 33      2023-02-15
# 34      2023-02-08
# 35      2023-02-09
# 36      2022-02-01
# 37      2023-02-09
# 38      2023-02-07
# 39      2022-03-15
# 40      2022-01-11
# 41      2022-12-21
# 42      2022-03-23
# 43      2022-10-15
# 44      2022-08-29
# 45            None
# 46            None
# 47      2022-12-01
# 48      2022-06-29
# 49      2022-03-05

# %%
#https://github.com/tyqGitHub/TYQ/tree/master/GACNNMDA - ????

# %%
#https://github.com/mofradlab - ?????? (PMID 36786404)

# %%
df1["Repo_created_at"] = None
df1["Repo_updated_at"] = None
for i in range(len(df1["PMID"])):
    try:
        df1["Repo_created_at"].iloc[i], df1["Repo_updated_at"].iloc[i] = pbmd.get_repo_info(str(df1["GitHub_link_clean"].iloc[i]))
    except:
        continue
# Out:
# Error with URL: https://api.github.com/repos/idslme/IDSL
# Status code: 404
# Error with URL: https://api.github.com/repos/umich-biostatistics/zGPS
# Status code: 404
# Error with URL: https://api.github.com/repos/aitgon/vtam, github.com
# Status code: 404
# Error with URL: https://api.github.com/repos/mofradlab/
# Status code: 404
# Error with URL: https://api.github.com/repos/peterman65/
# Status code: 404
# Error with URL: https://api.github.com/repos/rohdelab/nuclear_morphometry
# Status code: 404
# Error with URL: https://api.github.com/repos/CTC5/
# Status code: 404

# %%
df1 = df1[["PMID", "PubDate", "Repo_created_at", "Repo_updated_at", "DOI", "GitHub_link_raw", "GitHub_link_clean", "Journal", "Title", "Phrase"]]
df1[["PMID", "PubDate", "Repo_created_at", "Repo_updated_at", "DOI", "GitHub_link_clean", "Journal", "Title", "Phrase"]]
# Out:
#         PMID     PubDate Repo_created_at Repo_updated_at  \
# 0   36798707  2023-01-31      2022-09-11      2023-02-16
# 1   36798459  2023-02-08      2023-02-09      2023-02-15
# 2   36798308  2023-02-10            None            None
# 3   36798258  2023-02-12      2022-06-17      2023-01-31
# 4   36798154  2023-02-10      2022-04-18      2023-02-17
# ..       ...         ...             ...             ...
# 95  36740003  2023-02-03      2022-10-26      2022-10-26
# 96  36739821  2023-02-02      2023-01-23      2023-01-23
# 97  36739616  2023-02-05      2022-06-24      2022-07-04
# 98  36739333  2023-02-04      2022-07-06      2022-10-21
# 99  36738608  2023-01-28      2022-07-27      2023-02-15
#
#                                  DOI  \
# 0          10.3389/fpls.2023.1109314
# 1                               None
# 2          10.1101/2023.02.09.527886
# 3          10.1101/2023.02.11.528027
# 4          10.1101/2023.02.09.527740
# ..                               ...
# 95          10.1016/j.ab.2023.115075
# 96  10.1016/j.compbiomed.2023.106615
# 97                10.1002/gepi.22517
# 98        10.1038/s41437-023-00595-9
# 99        10.1016/j.cmpb.2023.107374
#
#                                     GitHub_link_clean  \
# 0                  https://github.com/syau-miao/DFSP/
# 1   https://github.com/BioinfoMachineLearning/bio-...
# 2                     https://github.com/idslme/IDSL/
# 3       https://github.com/gimelbrantlab/controlFreq/
# 4                 https://github.com/jennprk/diffsig/
# ..                                                ...
# 95              https://github.com/JYY625/DapNet-HLA/
# 96              https://github.com/NBU-CVMI/bx2s-net/
# 97          https://github.com/Kevin-walters/lapmapr/
# 98  https://github.com/ckgriswold/3-locus-autotetr...
# 99             https://github.com/ubern-mia/pyradise/
#
#                                          Journal  \
# 0                     Frontiers in plant science
# 1                                          ArXiv
# 2      bioRxiv : the preprint server for biology
# 3      bioRxiv : the preprint server for biology
# 4      bioRxiv : the preprint server for biology
# ..                                           ...
# 95                       Analytical biochemistry
# 96             Computers in biology and medicine
# 97                          Genetic epidemiology
# 98                                      Heredity
# 99  Computer methods and programs in biomedicine
#
#                                                 Title  \
# 0   DFSP: A fast and automatic distance field-base...
# 1   Geometry-Complete Diffusion for 3D Molecule Ge...
# 2   IDSL.CSA: Composite Spectra Analysis for Chemi...
# 3   Foreign RNA spike-ins enable accurate allele-s...
# 4   Diffsig: Associating Risk Factors With Mutatio...
# ..                                                ...
# 95  DapNet-HLA: Adaptive dual-attention mechanism ...
# 96  BX2S-Net: Learning to reconstruct 3D spinal st...
# 97  Bayesian multivariant fine mapping using the L...
# 98  Meiosis at three loci in autotetraploids: Prob...
# 99  PyRaDiSe: A Python package for DICOM-RT-based ...
#
#                                                Phrase
# 0   The source code can be found at \nhttps://gith...
# 1   The \nsource code, data, and instructions to t...
# 2   Detailed \ndocumentation and tutorials are pro...
# 3   VAILABILITY: Analysis pipeline for this approa...
# 4   Diffsig is implemented as an R package availab...
# ..                                                ...
# 95  The codes and \ndatasets are accessible at htt...
# 96  \nThe code is available at https://github.com/...
# 97  R code to implement the Laplace (and Gaussian)...
# 98  All Supplementary Information is \navailable a...
# 99  PyRaDiSe is available on \nhttps://github.com/...
#
# [100 rows x 9 columns]

# %%
df = pd.DataFrame()
df['PubDate'] = pd.to_datetime(df1['PubDate'])
df['Repo_created_at'] = pd.to_datetime(df1['Repo_created_at'])
df['Repo_updated_at'] = pd.to_datetime(df1['Repo_updated_at'])
df['Repo_created_at'] = (df['Repo_created_at'] - df['PubDate']).dt.days
df['Repo_updated_at'] = (df['Repo_updated_at'] - df['PubDate']).dt.days
df['PubDate'] = 0
df.dropna()
df
# Out:
#     PubDate  Repo_created_at  Repo_updated_at
# 0         0           -142.0             16.0
# 1         0              1.0              7.0
# 2         0              NaN              NaN
# 3         0           -240.0            -12.0
# 4         0           -298.0              7.0
# ..      ...              ...              ...
# 95        0           -100.0           -100.0
# 96        0            -10.0            -10.0
# 97        0           -226.0           -216.0
# 98        0           -213.0           -106.0
# 99        0           -185.0             18.0
#
# [100 rows x 3 columns]

# %%
fig, ax = plt.subplots()
    
for i, row in df.iterrows(): 
       
    ax.plot([row['PubDate'], row['Repo_created_at'], row['Repo_updated_at']], [i, i, i], color='black', linewidth=0.5, zorder=1)
    ax.scatter([row['Repo_created_at'], row['Repo_updated_at']], [i, i], s=60, facecolors=['green', 'blue'], edgecolors='black', zorder=2)

ax.axvline(x=0, color='red', linestyle='--', linewidth=2.5)
       
pubdate_marker = plt.Line2D([0,0],[0,0],marker='o', color='w', label='PubDate', markerfacecolor='red', markersize=8)
created_marker = plt.Line2D([0,0],[0,0],marker='o', color='w', label='Repo_created', markerfacecolor='green', markersize=8)
updated_marker = plt.Line2D([0,0],[0,0],marker='o', color='w', label='Repo_updated', markerfacecolor='blue', markersize=8)

ax.legend(handles=[pubdate_marker, created_marker, updated_marker])

plt.show()
