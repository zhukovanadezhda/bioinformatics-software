# %% [markdown]
# # Bioinformatics software

# %% [markdown]
# ## PubMed API Entrez Interactions

# %%
from datetime import datetime
import json
import re
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
import requests
import xmltodict
import dotenv

# %reload_ext autoreload
# %autoreload 2
import pbmd_tools as pbmd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19028\1968226334.py in <module>
#      10 import requests
#      11 import xmltodict
# ---> 12 import dotenv
#      13
#      14 get_ipython().run_line_magic('reload_ext', 'autoreload')
#
# ModuleNotFoundError: No module named 'dotenv'

# %% [markdown]
# #### Using Esearch to get the list of IDs of the articles containing "github.com" in their abstract

# %%
API_KEY = pbmd.read_tokens[0]
db = "pubmed"
domain = "https://www.ncbi.nlm.nih.gov/entrez/eutils"
nresults = 15000
retmode = "json"
queries = []
for i in range(2009,2024):
    queries.append(f'((github.com[Title/Abstract])) AND (("{i}/01/01"[Date - Publication] : "{i}/12/31"[Date - Publication]))')
# Out:
# [autoreload of pbmd_tools failed: Traceback (most recent call last):
#   File "C:\Users\nadia\anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\nadia\anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\nadia\anaconda3\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\nadia\anaconda3\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\nadia\bioinformatics-software\pbmd_tools.py", line 4, in <module>
#     import dotenv
# ModuleNotFoundError: No module named 'dotenv'
# ]
# [autoreload of pbmd_tools failed: Traceback (most recent call last):
#   File "C:\Users\nadia\anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\nadia\anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\nadia\anaconda3\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\nadia\anaconda3\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\nadia\bioinformatics-software\pbmd_tools.py", line 4, in <module>
#     import dotenv
# ModuleNotFoundError: No module named 'dotenv'
# ]
# [autoreload of pbmd_tools failed: Traceback (most recent call last):
#   File "C:\Users\nadia\anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\nadia\anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\nadia\anaconda3\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "C:\Users\nadia\anaconda3\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\nadia\bioinformatics-software\pbmd_tools.py", line 4, in <module>
#     import dotenv
# ModuleNotFoundError: No module named 'dotenv'
# ]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19028\557568805.py in <module>
# ----> 1 API_KEY = pbmd.read_tokens[0]
#       2 db = "pubmed"
#       3 domain = "https://www.ncbi.nlm.nih.gov/entrez/eutils"
#       4 nresults = 15000
#       5 retmode = "json"
#
# AttributeError: module 'pbmd_tools' has no attribute 'read_tokens'

# %%
PMIDs = []
stats = {}
for query in tqdm(queries):
    nb = 0
    queryLinkSearch = f"{domain}/esearch.fcgi?db={db}&retmax={nresults}&retmode={retmode}&term={query}&api_key={API_KEY}"
    response = requests.get(queryLinkSearch)
    pubmedJson = response.json()
    for id in pubmedJson["esearchresult"]["idlist"]:
        nb += 1
        PMIDs.append(id)
    stats[query[38:42]] = nb
PMIDs = set(PMIDs)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [00:14<00:00,  1.04it/s]

# %%
years = list(stats.keys())
values = list(stats.values())

plt.bar(years, values, color='cadetblue')

plt.xlabel('Year')
plt.ylabel('Number of publications')
plt.title('Publications per year')

for i, value in enumerate(values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.xticks(rotation=90)

plt.show()

# %%
with open("PMIDs.txt", "w") as f:
    for PMID in PMIDs:
        f.write(str(PMID)+"\n")

# %%
# https://pubmed.ncbi.nlm.nih.gov/26262258/ - No DOI in PubMed although there is one in the full text of the article (not from ArXiv), and there are a lot of them
# https://pubmed.ncbi.nlm.nih.gov/28269829/ - they give a wrong link https://github.com/SBU-BMI/imageboxs://github.com/SBU-BMI/imagebox but if you use this link :
# https://github.com/SBU-BMI/imagebox it works. Yet, i am not sure that it is actually what we are looking for since the also provide another link to github.io 
# (also incorect) and i think it's more likely that their code is there

# %% [markdown]
# #### Using Efetch to get all the necessary information about these articles

# %%
#100%|██████████████████████████████████████████████████████████████████████████| 14072/14072 [2:31:15<00:00,  1.55it/s]

results = []
log_error_sum = []
for PMID in tqdm(PMIDs):
        results.append(pbmd.get_summary(PMID, log_error_sum)[:-1])

# %%
df1 = pd.DataFrame.from_records(results)
df1 = df1.rename(columns={0: 'PubDate', 1: 'DOI', 2: 'Journal', 3: 'Title', 4: 'Abstract'})
new_column = pd.read_csv('PMIDs.txt', header=None, names=['PMID'], lineterminator='\n')
df1.insert(loc=0, column='PMID', value=new_column)

df1[df1.isnull().any(axis=1)]
# Out:
#            PMID     PubDate   DOI  \
# 243    26713261        None  None
# 276    26262258        2015  None
# 312    26958216  2015-11-05  None
# 313    26958160  2015-11-05  None
# 515    28269829  2017-02-10  None
# ...         ...         ...   ...
# 13579  36776820  2023-02-02  None
# 13757  36655793        None  None
# 13895  36540970        2023  None
# 13896  36540967        2023  None
# 13940  36495018        None  None
#
#                                                  Journal  \
# 243                                                 None
# 276         Studies in health technology and informatics
# 312    AMIA ... Annual Symposium proceedings. AMIA Sy...
# 313    AMIA ... Annual Symposium proceedings. AMIA Sy...
# 515    AMIA ... Annual Symposium proceedings. AMIA Sy...
# ...                                                  ...
# 13579                                              ArXiv
# 13757                                               None
# 13895  Pacific Symposium on Biocomputing. Pacific Sym...
# 13896  Pacific Symposium on Biocomputing. Pacific Sym...
# 13940                                               None
#
#                                                    Title  \
# 243                                                 None
# 276    Computationally Comparing and Analyzing All Pu...
# 312    Reproducing a Prospective Clinical Study as a ...
# 313    OpenHealth Platform for Interactive Contextual...
# 515    Safe "cloudification" of large images through ...
# ...                                                  ...
# 13579  Transport-based morphometry of nuclear structu...
# 13757                                               None
# 13895  Selecting Clustering Algorithms for Identity-B...
# 13896  A Graph Coarsening Algorithm for Compressing R...
# 13940                                               None
#
#                                                 Abstract
# 243                                                 None
# 276    The clinical literature presents four differen...
# 312    In this paper we sought to reproduce, as a com...
# 313    The financial incentives for data science appl...
# 515    The "Box model" allows users with no particula...
# ...                                                  ...
# 13579  Alterations in nuclear morphology are useful a...
# 13757                                               None
# 13895  Groups of distantly related individuals who sh...
# 13896  Graph-based algorithms have become essential i...
# 13940                                               None
#
# [151 rows x 6 columns]

# %%
df1.to_csv('articles.tsv', sep='\t', index=False)

# %%
with open("errors_pubmed.txt", "w") as f:
    for line in log_error_sum:
        f.write(line)

# %% [markdown]
# ## Cleaning obtained data

# %%
df1 = pd.read_csv('articles.tsv', sep='\t')
# Out:
#            PMID     PubDate                            DOI  \
# 0      21595876  2011-05-19       10.1186/gb-2011-12-5-r44
# 1      21169373  2010-12-17  10.1093/bioinformatics/btq693
# 2      20935049  2010-10-08             10.1093/nar/gkq866
# 3      20798169  2010-08-26  10.1093/bioinformatics/btq455
# 4      20562450  2010-06-20  10.1093/bioinformatics/btq320
# ...         ...         ...                            ...
# 14067  35900371  2022-07-28     10.1007/s00125-022-05763-w
# 14068  35882682  2022-07-26     10.1007/s10439-022-03018-8
# 14069  35007471  2022-01-10  10.1080/07391102.2021.2024450
# 14070  36819073  2021-09-11  10.1080/02664763.2021.1973387
# 14071  34177125  2021-06-17     10.1007/s00521-021-06163-8
#
#                                             Journal  \
# 0                                    Genome biology
# 1                  Bioinformatics (Oxford, England)
# 2                            Nucleic acids research
# 3                  Bioinformatics (Oxford, England)
# 4                  Bioinformatics (Oxford, England)
# ...                                             ...
# 14067                                  Diabetologia
# 14068              Annals of biomedical engineering
# 14069  Journal of biomolecular structure & dynamics
# 14070                 Journal of applied statistics
# 14071               Neural computing & applications
#
#                                                    Title  \
# 0      EMIRGE: reconstruction of full-length ribosoma...
# 1      SAIL--a software system for sample and phenoty...
# 2      The Sol Genomics Network (solgenomics.net): gr...
# 3      METAREP: JCVI metagenomics reports--an open so...
# 4      Bridges: a tool for identifying local similari...
# ...                                                  ...
# 14067  Smoking, use of smokeless tobacco, HLA genotyp...
# 14068  A Validated Open-Source Shoulder Finite Elemen...
# 14069  {'i': 'in silico', '#text': 'QPoweredCompound2...
# 14070  Identification of novel genes for triple-negat...
# 14071  Enhanced balancing GAN: minority-class image g...
#
#                                                 Abstract
# 0      Recovery of ribosomal small subunit genes by a...
# 1      The Sample avAILability system-SAIL-is a web b...
# 2      The Sol Genomics Network (SGN; http://solgenom...
# 3      JCVI Metagenomics Reports (METAREP) is a Web 2...
# 4      Bridges is a heuristic search tool that uses s...
# ...                                                  ...
# 14067  Smoking and use of smokeless tobacco (snus) ar...
# 14068  Understanding the loads and stresses on differ...
# 14069  {'i': 'in silico', '#text': 'Network data is c...
# 14070  {'i': 'p', '#text': 'Triple-negative breast ca...
# 14071  Generative adversarial networks (GANs) are one...
#
# [14072 rows x 6 columns]

# %%
for id_iter in tqdm(df1["PMID"]):
    df1.loc[df1["PMID"] == id_iter,"GitHub_link_raw"] = ", ".join(pbmd.get_link(df1, id_iter))
    df1.loc[df1["PMID"] == id_iter,"GitHub_link_clean"] = ", ".join(pbmd.clean_link(df1, id_iter))
    df1.loc[df1["PMID"] == id_iter, "Phrase"] = str(pbmd.get_phrase_with_link(df1, id_iter))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 11424/11424 [00:36<00:00, 315.41it/s]

# %%
df1.to_csv('articles_with_links.tsv', sep='\t', index=False)

# %% [markdown]
# ## GitHub API Interactions

# %%
#To find out about repositories that were not accessed, consult the log_error variable. 

df1["Repo_created_at"] = None
df1["Repo_updated_at"] = None
log_error_repo = []
for i in tqdm(range(len(df1["PMID"]))):
    try:
        df1["Repo_created_at"].iloc[i], df1["Repo_updated_at"].iloc[i], log_error_repo = pbmd.get_repo_info(str(df1["GitHub_link_clean"].iloc[i]), log_error_repo)
    except:
        log_error_repo.append(f"Error with PMID: {df1['PMID'][i]}")
        continue
df1 = df1.reindex(columns=["PMID", "PubDate", "Repo_created_at", "Repo_updated_at", "DOI", "Journal", "Title", "GitHub_link_raw", "GitHub_link_clean", "Phrase", "Abstract"])
# Out:
#   0%|                                                                                        | 0/11424 [00:00<?, ?it/s]C:\Users\nadia\AppData\Local\Temp\ipykernel_19028\2414177476.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Repo_created_at"].iloc[i], df1["Repo_updated_at"].iloc[i], log_error_repo = pbmd.get_repo_info(str(df1["GitHub_link_clean"].iloc[i]), log_error_repo)
# 100%|████████████████████████████████████████████████████████████████████████████| 11424/11424 [57:20<00:00,  3.32it/s]

# %%
with open("errors_github.txt", "w") as f:
    for line in log_error_repo:
        f.write(line)

# %%
df1[df1['Repo_created_at'].isna()]
# Out:
#            PMID     PubDate                            DOI  \
# 1      21169373  2010-12-17  10.1093/bioinformatics/btq693
# 2      20935049  2010-10-08             10.1093/nar/gkq866
# 8      23272111  2012-12-14   10.1371/journal.pone.0051511
# 12     22235263  2012-01-03   10.1371/journal.pone.0029115
# 14     22151646  2011-10-05    10.1186/1471-2105-12-S9-S11
# ...         ...         ...                            ...
# 11374  36611253    2023-Jan            10.1093/bib/bbac598
# 11385  36599414  2023-01-04   10.1021/acs.analchem.1c03566
# 11401  36535036  2023-01-18       10.1088/1741-2552/acacca
# 11403  36528809    2023-Jan            10.1093/bib/bbac548
# 11414  36440972    2023-Jan            10.1093/bib/bbac497
#
#                                 Journal  \
# 1      Bioinformatics (Oxford, England)
# 2                Nucleic acids research
# 8                              PloS one
# 12                             PloS one
# 14                   BMC bioinformatics
# ...                                 ...
# 11374       Briefings in bioinformatics
# 11385              Analytical chemistry
# 11401     Journal of neural engineering
# 11403       Briefings in bioinformatics
# 11414       Briefings in bioinformatics
#
#                                                    Title  \
# 1      SAIL--a software system for sample and phenoty...
# 2      The Sol Genomics Network (solgenomics.net): gr...
# 8      MultiMetEval: comparative and multi-objective ...
# 12     Bayesian variable selection in searching for a...
# 14     Constraints on genes shape long-term conservat...
# ...                                                  ...
# 11374  Deleterious synonymous mutation identification...
# 11385  LipidA-IDER to Explore the Global Lipid A Repe...
# 11401  Transfer learning of an ensemble of DNNs for S...
# 11403  Multi-view contrastive heterogeneous graph att...
# 11414  Extraction of microRNA-target interaction sent...
#
#                                                 Abstract  \
# 1      The Sample avAILability system-SAIL-is a web b...
# 2      The Sol Genomics Network (SGN; http://solgenom...
# 8      Comparative metabolic modelling is emerging as...
# 12     Although complex diseases and traits are thoug...
# 14     Many metazoan genomes conserve chromosome-scal...
# ...                                                  ...
# 11374  Although previous studies have revealed that s...
# 11385  {'sup': ['2', '2'], 'i': ['Escherichia coli', ...
# 11401  {'i': ['Objective.', 'Approach.', 'k', 'Main r...
# 11403  Exploring the potential long noncoding RNA (ln...
# 11414  MicroRNA (miRNA)-target interaction (MTI) play...
#
#                                          GitHub_link_raw  \
# 1                                       github.com/sail.
# 2                                             github.com
# 8          github.com/PiotrZakrzewski/MetEval/downloads.
# 12                                    github.com/to-mi/.
# 14                          github.com/putnamlab/dcj-c.A
# ...                                                  ...
# 11374                   github.com/xialab-ahu/seDSM.git.
# 11385  github.com/Systems-Biology-Of-Lipid-Metabolism...
# 11401         github.com/osmanberke/Ensemble-of-DNNs.Our
# 11403                      github.com/zhaoxs686/MCHNLDA.
# 11414                                   github.com/qi29.
#
#                                        GitHub_link_clean  \
# 1                               https://github.com/sail/
# 2                                    https://github.com/
# 8      https://github.com/PiotrZakrzewski/MetEval/dow...
# 12                             https://github.com/to-mi/
# 14                 https://github.com/putnamlab/dcj-c.A/
# ...                                                  ...
# 11374           https://github.com/xialab-ahu/seDSM.git/
# 11385  https://github.com/Systems-Biology-Of-Lipid-Me...
# 11401  https://github.com/osmanberke/Ensemble-of-DNNs...
# 11403              https://github.com/zhaoxs686/MCHNLDA/
# 11414                           https://github.com/qi29/
#
#                                                   Phrase Repo_created_at  \
# 1      AIL is available under Aferro-GPL open source ...            None
# 2      All code and development work is publicly visi...            None
# 8      Sources and binaries of MultiMetEval are freel...            None
# 12     i/research/mm/bmagwa/ and https://github.com/t...            None
# 14     Our software implements a flexible strategy fo...            None
# ...                                                  ...             ...
# 11374  The source code of seDSM is freely accessible ...            None
# 11385  LipidA-IDER is freely available at https://git...            None
# 11401  Code is available for reproducibility:https://...            None
# 11403  he code and data of proposed framework is free...            None
# 11414  Source code and corpus are publicly available ...            None
#
#       Repo_updated_at
# 1                None
# 2                None
# 8                None
# 12               None
# 14               None
# ...               ...
# 11374            None
# 11385            None
# 11401            None
# 11403            None
# 11414            None
#
# [6257 rows x 11 columns]

# %%
# PMID = 36789260 - 2 links
#https://github.com/tyqGitHub/TYQ/tree/master/GACNNMDA - ????
#https://github.com/mofradlab - ?????? (PMID 36786404)
# PMID = 26124555 - a space in the link lol

# %%
df = pd.DataFrame()
df["PubDate"] = pd.to_datetime(df1["PubDate"])
df["Repo_created_at"] = pd.to_datetime(df1["Repo_created_at"])
df["Repo_updated_at"] = pd.to_datetime(df1["Repo_updated_at"])
df["Repo_created_at"] = (df["Repo_created_at"] - df["PubDate"]).dt.days
df["Repo_updated_at"] = (df["Repo_updated_at"] - df["PubDate"]).dt.days
df["PubDate"] = 0

# %%
df = df.dropna(how='any')
df = df.sort_values(by=['Repo_created_at', 'Repo_updated_at'], ascending=[True, True])
df = df.reset_index(drop=True)

# %%
df
# Out:
#       PubDate  Repo_created_at  Repo_updated_at
# 0           0          -3769.0            393.0
# 1           0          -3746.0            245.0
# 2           0          -3467.0            375.0
# 3           0          -3210.0            258.0
# 4           0          -3106.0           1680.0
# ...       ...              ...              ...
# 5162        0           2034.0           2706.0
# 5163        0           2099.0           2528.0
# 5164        0           2315.0           3066.0
# 5165        0           2543.0           2543.0
# 5166        0           3182.0           4099.0
#
# [5167 rows x 3 columns]

# %%
fig, ax = plt.subplots()


for i, row in tqdm(df.head(100).iterrows()):
    
    ax.plot([row['Repo_created_at'], row['Repo_updated_at']], [i, i], color='black', linewidth=0.5, zorder=3)
    ax.scatter([row['Repo_created_at'], row['Repo_updated_at']], [i, i], s=10, facecolors=['green', 'blue'], edgecolors='black', zorder=4)

ax.axvline(x=0, color='red', linestyle='--', linewidth=2.5)
       
pubdate_marker = plt.Line2D([0,0],[0,0],linestyle='--', color='red', label='PubDate', markerfacecolor='red', linewidth=3)
created_marker = plt.Line2D([0,0],[0,0],marker='o', color='w', label='Repo_created', markerfacecolor='green', markersize=8)
updated_marker = plt.Line2D([0,0],[0,0],marker='o', color='w', label='Repo_updated', markerfacecolor='blue', markersize=8)

ax.legend(handles=[pubdate_marker, created_marker, updated_marker])

plt.show()
# Out:
# 100it [00:00, 156.05it/s]
